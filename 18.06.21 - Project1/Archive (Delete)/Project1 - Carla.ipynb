# %% [markdown]
# ### News Mood
#
# In this activity, we are going to review Tweepy.
#
# BBC, CBS, CNN, Fox, and New York times
# - - -

# %%
# Dependencies
import numpy as np
import pandas as pd
import tweepy
import json
import time
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
from config import (consumer_key, consumer_secret, 
                    access_token, access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# "Real Person" Filters
min_tweets = 5
max_tweets = 10000
max_followers = 2500
max_following = 2500
lang = "en"

# %%
api.search("gavin newsom")
# Out:
# {'search_metadata': {'completed_in': 0.054,
#   'count': 15,
#   'max_id': 1006725143178153985,
#   'max_id_str': '1006725143178153985',
#   'next_results': '?max_id=1006719468742103039&q=gavin%20newsom&include_entities=1',
#   'query': 'gavin+newsom',
#   'refresh_url': '?since_id=1006725143178153985&q=gavin%20newsom&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:29:12 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'yahoo.com/news/californi…',
#       'expanded_url': 'https://www.yahoo.com/news/californias-gavin-newsom-wants-lead-way-post-bernie-post-hillary-party-160041273.html?.tsrc=fauxdal',
#       'indices': [85, 108],
#       'url': 'https://t.co/RcZ9rA7xbb'},
#      {'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1006725143178153985',
#       'indices': [117, 140],
#       'url': 'https://t.co/qJuWlbzDas'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006725143178153985,
#    'id_str': '1006725143178153985',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "California's Gavin Newsom wants to lead the way to a post-Bernie, post-Hillary party https://t.co/RcZ9rA7xbb Hollyw… https://t.co/qJuWlbzDas",
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Oct 10 01:27:50 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': True,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 84,
#     'follow_request_sent': False,
#     'followers_count': 0,
#     'following': False,
#     'friends_count': 33,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 785290711264595968,
#     'id_str': '785290711264595968',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': '',
#     'name': 'svetlana',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'russianimigrant',
#     'statuses_count': 338,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:19:21 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3995778614,
#       'id_str': '3995778614',
#       'indices': [3, 10],
#       'name': 'Kambree Kawahine Koa',
#       'screen_name': 'KamVTV'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006722662549344256,
#    'id_str': '1006722662549344256',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 293,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Jun 12 23:23:29 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1006678403355852800',
#        'indices': [117, 140],
#        'url': 'https://t.co/jNEkRd0E09'}],
#      'user_mentions': []},
#     'favorite_count': 334,
#     'favorited': False,
#     'geo': None,
#     'id': 1006678403355852800,
#     'id_str': '1006678403355852800',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 293,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 bill… https://t.co/jNEkRd0E09',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Oct 23 22:32:20 +0000 2015',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '✨Native Texan 🇨🇱 ✨ VP of Field Relations in Orange County, CA ✨Political News Contributor ✨Mindset/Leadership Speaker✨Independent✨',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'tinyurl.com/yawp5j9v',
#          'expanded_url': 'https://tinyurl.com/yawp5j9v',
#          'indices': [0, 23],
#          'url': 'https://t.co/yKGoetg6lc'}]}},
#      'favourites_count': 54447,
#      'follow_request_sent': False,
#      'followers_count': 107779,
#      'following': False,
#      'friends_count': 1524,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 3995778614,
#      'id_str': '3995778614',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 419,
#      'location': 'Los Angeles, CA ✈️ Dallas, TX',
#      'name': 'Kambree Kawahine Koa',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3995778614/1512949404',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_link_color': '221122',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'KamVTV',
#      'statuses_count': 49374,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/yKGoetg6lc',
#      'utc_offset': None,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @KamVTV: I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 billion. Gavin N…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Jun 11 22:52:09 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Liberty,Constitution,End theft/corruption. #trader RV, basketball, sailing,pilot,scuba @constituteUS @Hillsdale',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 378,
#     'follow_request_sent': False,
#     'followers_count': 521,
#     'following': False,
#     'friends_count': 904,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1507248036,
#     'id_str': '1507248036',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 9,
#     'location': 'Texas',
#     'name': 'Jim Morris',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1507248036/1457821266',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/708779884949057537/sKBKsi70_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/708779884949057537/sKBKsi70_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'J44morris',
#     'statuses_count': 4556,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:18:32 +0000 2018',
#    'entities': {'hashtags': [{'indices': [64, 74], 'text': 'TeamGavin'}],
#     'symbols': [],
#     'urls': [{'display_url': 'uk.news.yahoo.com/californias-ga…',
#       'expanded_url': 'https://uk.news.yahoo.com/californias-gavin-newsom-wants-lead-way-post-bernie-post-hillary-party-160041273.html?guccounter=1',
#       'indices': [76, 99],
#       'url': 'https://t.co/8aulyh9ycN'}],
#     'user_mentions': [{'id': 474351727,
#       'id_str': '474351727',
#       'indices': [3, 14],
#       'name': 'Mark Ridley-Thomas',
#       'screen_name': 'MRTempower'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006722458135642112,
#    'id_str': '1006722458135642112',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Jun 12 18:56:00 +0000 2018',
#     'entities': {'hashtags': [{'indices': [48, 58], 'text': 'TeamGavin'}],
#      'symbols': [],
#      'urls': [{'display_url': 'uk.news.yahoo.com/californias-ga…',
#        'expanded_url': 'https://uk.news.yahoo.com/californias-gavin-newsom-wants-lead-way-post-bernie-post-hillary-party-160041273.html?guccounter=1',
#        'indices': [60, 83],
#        'url': 'https://t.co/8aulyh9ycN'}],
#      'user_mentions': []},
#     'favorite_count': 6,
#     'favorited': False,
#     'geo': None,
#     'id': 1006611091315539969,
#     'id_str': '1006611091315539969',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Already time to get busy. Let’s go!@GavinNewsom #TeamGavin  https://t.co/8aulyh9ycN',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jan 25 22:23:04 +0000 2012',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': "LA County Supervisor Mark Ridley-Thomas, representing 2nd District on Los Angeles County Board of Supervisors (Non-Gov't.Twitter Account). #FBR",
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'markridley-thomas.com',
#          'expanded_url': 'http://www.markridley-thomas.com/',
#          'indices': [0, 23],
#          'url': 'https://t.co/1qkQmtoSha'}]}},
#      'favourites_count': 407,
#      'follow_request_sent': False,
#      'followers_count': 27499,
#      'following': False,
#      'friends_count': 22947,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 474351727,
#      'id_str': '474351727',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 204,
#      'location': 'Los Angeles',
#      'name': 'Mark Ridley-Thomas',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/474351727/1370969543',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/844065216719544324/dBx-u80F_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/844065216719544324/dBx-u80F_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'MRTempower',
#      'statuses_count': 7870,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/1qkQmtoSha',
#      'utc_offset': None,
#      'verified': True}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @MRTempower: Already time to get busy. Let’s go!@GavinNewsom #TeamGavin  https://t.co/8aulyh9ycN',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Sep 11 23:35:24 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The largest urban voter registration, education, and participation project for African Americans in California. Founder @MRTEmpower #WokeVote18 #FBR',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'africanamericanvoterrep.org',
#         'expanded_url': 'http://www.africanamericanvoterrep.org',
#         'indices': [0, 22],
#         'url': 'http://t.co/4QMnMnQNcC'}]}},
#     'favourites_count': 539,
#     'follow_request_sent': False,
#     'followers_count': 16627,
#     'following': False,
#     'friends_count': 15456,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 818418566,
#     'id_str': '818418566',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 108,
#     'location': 'California',
#     'name': 'African American Voter REP',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/818418566/1400795806',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/967500373970771968/NFKQAUll_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/967500373970771968/NFKQAUll_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'AfAmVoterREP',
#     'statuses_count': 2407,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://t.co/4QMnMnQNcC',
#     'utc_offset': None,
#     'verified': True}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:17:14 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3995778614,
#       'id_str': '3995778614',
#       'indices': [3, 10],
#       'name': 'Kambree Kawahine Koa',
#       'screen_name': 'KamVTV'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006722129604333573,
#    'id_str': '1006722129604333573',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 293,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Jun 12 23:23:29 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1006678403355852800',
#        'indices': [117, 140],
#        'url': 'https://t.co/jNEkRd0E09'}],
#      'user_mentions': []},
#     'favorite_count': 334,
#     'favorited': False,
#     'geo': None,
#     'id': 1006678403355852800,
#     'id_str': '1006678403355852800',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 293,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 bill… https://t.co/jNEkRd0E09',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Oct 23 22:32:20 +0000 2015',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '✨Native Texan 🇨🇱 ✨ VP of Field Relations in Orange County, CA ✨Political News Contributor ✨Mindset/Leadership Speaker✨Independent✨',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'tinyurl.com/yawp5j9v',
#          'expanded_url': 'https://tinyurl.com/yawp5j9v',
#          'indices': [0, 23],
#          'url': 'https://t.co/yKGoetg6lc'}]}},
#      'favourites_count': 54447,
#      'follow_request_sent': False,
#      'followers_count': 107779,
#      'following': False,
#      'friends_count': 1524,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 3995778614,
#      'id_str': '3995778614',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 419,
#      'location': 'Los Angeles, CA ✈️ Dallas, TX',
#      'name': 'Kambree Kawahine Koa',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3995778614/1512949404',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_link_color': '221122',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'KamVTV',
#      'statuses_count': 49374,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/yKGoetg6lc',
#      'utc_offset': None,
#      'verified': True}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @KamVTV: I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 billion. Gavin N…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Sep 20 20:58:52 +0000 2013',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Home Is Where The Heart Is....',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 50710,
#     'follow_request_sent': False,
#     'followers_count': 6215,
#     'following': False,
#     'friends_count': 5356,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1887844819,
#     'id_str': '1887844819',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 114,
#     'location': 'Florida',
#     'name': 'Sunny Flowers',
#     'notifications': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1887844819/1516014379',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000484293408/70d425e944b50df702acfe192f3471c8_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000484293408/70d425e944b50df702acfe192f3471c8_normal.jpeg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': '850Sunny',
#     'statuses_count': 87692,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:15:56 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3995778614,
#       'id_str': '3995778614',
#       'indices': [3, 10],
#       'name': 'Kambree Kawahine Koa',
#       'screen_name': 'KamVTV'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006721803329331202,
#    'id_str': '1006721803329331202',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 293,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Jun 12 23:23:29 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1006678403355852800',
#        'indices': [117, 140],
#        'url': 'https://t.co/jNEkRd0E09'}],
#      'user_mentions': []},
#     'favorite_count': 334,
#     'favorited': False,
#     'geo': None,
#     'id': 1006678403355852800,
#     'id_str': '1006678403355852800',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 293,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 bill… https://t.co/jNEkRd0E09',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Oct 23 22:32:20 +0000 2015',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '✨Native Texan 🇨🇱 ✨ VP of Field Relations in Orange County, CA ✨Political News Contributor ✨Mindset/Leadership Speaker✨Independent✨',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'tinyurl.com/yawp5j9v',
#          'expanded_url': 'https://tinyurl.com/yawp5j9v',
#          'indices': [0, 23],
#          'url': 'https://t.co/yKGoetg6lc'}]}},
#      'favourites_count': 54447,
#      'follow_request_sent': False,
#      'followers_count': 107779,
#      'following': False,
#      'friends_count': 1524,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 3995778614,
#      'id_str': '3995778614',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 419,
#      'location': 'Los Angeles, CA ✈️ Dallas, TX',
#      'name': 'Kambree Kawahine Koa',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3995778614/1512949404',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_link_color': '221122',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'KamVTV',
#      'statuses_count': 49374,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/yKGoetg6lc',
#      'utc_offset': None,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @KamVTV: I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 billion. Gavin N…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Nov 20 03:00:42 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 21609,
#     'follow_request_sent': False,
#     'followers_count': 327,
#     'following': False,
#     'friends_count': 234,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 4296482000,
#     'id_str': '4296482000',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 10,
#     'location': '',
#     'name': 'Christine L. Roy',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/908738940340862976/qZKFVzKF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/908738940340862976/qZKFVzKF_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'christinelroy',
#     'statuses_count': 26004,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:13:01 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3995778614,
#       'id_str': '3995778614',
#       'indices': [3, 10],
#       'name': 'Kambree Kawahine Koa',
#       'screen_name': 'KamVTV'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006721067954638851,
#    'id_str': '1006721067954638851',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 293,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Jun 12 23:23:29 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1006678403355852800',
#        'indices': [117, 140],
#        'url': 'https://t.co/jNEkRd0E09'}],
#      'user_mentions': []},
#     'favorite_count': 334,
#     'favorited': False,
#     'geo': None,
#     'id': 1006678403355852800,
#     'id_str': '1006678403355852800',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 293,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 bill… https://t.co/jNEkRd0E09',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Oct 23 22:32:20 +0000 2015',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '✨Native Texan 🇨🇱 ✨ VP of Field Relations in Orange County, CA ✨Political News Contributor ✨Mindset/Leadership Speaker✨Independent✨',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'tinyurl.com/yawp5j9v',
#          'expanded_url': 'https://tinyurl.com/yawp5j9v',
#          'indices': [0, 23],
#          'url': 'https://t.co/yKGoetg6lc'}]}},
#      'favourites_count': 54447,
#      'follow_request_sent': False,
#      'followers_count': 107779,
#      'following': False,
#      'friends_count': 1524,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 3995778614,
#      'id_str': '3995778614',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 419,
#      'location': 'Los Angeles, CA ✈️ Dallas, TX',
#      'name': 'Kambree Kawahine Koa',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3995778614/1512949404',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_link_color': '221122',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'KamVTV',
#      'statuses_count': 49374,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/yKGoetg6lc',
#      'utc_offset': None,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @KamVTV: I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 billion. Gavin N…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jun 17 20:57:37 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '#pro-life. Back the Blue! Israel 💙 #MAGA My USAF dad is my hero. Our veterans deserve the best. I love CA. Sending my girl to San Jose State.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 168761,
#     'follow_request_sent': False,
#     'followers_count': 5625,
#     'following': False,
#     'friends_count': 4853,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 48113045,
#     'id_str': '48113045',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 11,
#     'location': '',
#     'name': 'I love this land. God bless the USA!',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/48113045/1510033585',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/998790873432309760/JipqgBJR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998790873432309760/JipqgBJR_normal.jpg',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'caitie1877',
#     'statuses_count': 81350,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:11:51 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1006720776882479106',
#       'indices': [117, 140],
#       'url': 'https://t.co/IgrdKL3wVl'}],
#     'user_mentions': [{'id': 863620345957371904,
#       'id_str': '863620345957371904',
#       'indices': [0, 13],
#       'name': '#ProLifer@Kate1Kincaid',
#       'screen_name': 'Kate1Kincaid'},
#      {'id': 963418436,
#       'id_str': '963418436',
#       'indices': [14, 28],
#       'name': '🦅🇺🇸SAKramer🇺🇸🦅',
#       'screen_name': 'skramerbyu_82'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006720776882479106,
#    'id_str': '1006720776882479106',
#    'in_reply_to_screen_name': 'Kate1Kincaid',
#    'in_reply_to_status_id': 1006714926554021890,
#    'in_reply_to_status_id_str': '1006714926554021890',
#    'in_reply_to_user_id': 863620345957371904,
#    'in_reply_to_user_id_str': '863620345957371904',
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '@Kate1Kincaid @skramerbyu_82 Unfortunately, it’s too late!  Our only hope was Travis Allen, but the deep state rigg… https://t.co/IgrdKL3wVl',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Mar 03 04:09:15 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Wife, mother, grandmother. California conservative, follower of Jesus ✝️. I love my country, and support our president! #MAGA🇺🇸 @NewGoldenState @NewCalif',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 2498,
#     'follow_request_sent': False,
#     'followers_count': 348,
#     'following': False,
#     'friends_count': 684,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2378054675,
#     'id_str': '2378054675',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 0,
#     'location': 'Californa, USA',
#     'name': 'The Warden',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2378054675/1525097039',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/964611483190493185/g_XY1VSV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964611483190493185/g_XY1VSV_normal.jpg',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'Leslie97606493',
#     'statuses_count': 1033,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:11:46 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3995778614,
#       'id_str': '3995778614',
#       'indices': [3, 10],
#       'name': 'Kambree Kawahine Koa',
#       'screen_name': 'KamVTV'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006720754254336000,
#    'id_str': '1006720754254336000',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 293,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Jun 12 23:23:29 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1006678403355852800',
#        'indices': [117, 140],
#        'url': 'https://t.co/jNEkRd0E09'}],
#      'user_mentions': []},
#     'favorite_count': 334,
#     'favorited': False,
#     'geo': None,
#     'id': 1006678403355852800,
#     'id_str': '1006678403355852800',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 293,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 bill… https://t.co/jNEkRd0E09',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Oct 23 22:32:20 +0000 2015',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '✨Native Texan 🇨🇱 ✨ VP of Field Relations in Orange County, CA ✨Political News Contributor ✨Mindset/Leadership Speaker✨Independent✨',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'tinyurl.com/yawp5j9v',
#          'expanded_url': 'https://tinyurl.com/yawp5j9v',
#          'indices': [0, 23],
#          'url': 'https://t.co/yKGoetg6lc'}]}},
#      'favourites_count': 54447,
#      'follow_request_sent': False,
#      'followers_count': 107779,
#      'following': False,
#      'friends_count': 1524,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 3995778614,
#      'id_str': '3995778614',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 419,
#      'location': 'Los Angeles, CA ✈️ Dallas, TX',
#      'name': 'Kambree Kawahine Koa',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3995778614/1512949404',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_link_color': '221122',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'KamVTV',
#      'statuses_count': 49374,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/yKGoetg6lc',
#      'utc_offset': None,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @KamVTV: I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 billion. Gavin N…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun May 31 16:40:47 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Christian \nMarried \nConservative \nPatriot\n#2A,\nPro Israel,\nBless ourMilitary,\nBluelivesMatter,\nNRA,build the wall,no sharia law,Constitution,\nAR 15 Owner',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 27908,
#     'follow_request_sent': False,
#     'followers_count': 1127,
#     'following': False,
#     'friends_count': 1214,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 3231834818,
#     'id_str': '3231834818',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 48,
#     'location': 'Bentonville, AR',
#     'name': 'Kevin Beisley',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3231834818/1519878561',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/969070162761666561/STlKZbMB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/969070162761666561/STlKZbMB_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'beisley33',
#     'statuses_count': 66524,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:11:37 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3995778614,
#       'id_str': '3995778614',
#       'indices': [3, 10],
#       'name': 'Kambree Kawahine Koa',
#       'screen_name': 'KamVTV'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006720715490553858,
#    'id_str': '1006720715490553858',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 293,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Jun 12 23:23:29 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1006678403355852800',
#        'indices': [117, 140],
#        'url': 'https://t.co/jNEkRd0E09'}],
#      'user_mentions': []},
#     'favorite_count': 334,
#     'favorited': False,
#     'geo': None,
#     'id': 1006678403355852800,
#     'id_str': '1006678403355852800',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 293,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 bill… https://t.co/jNEkRd0E09',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Oct 23 22:32:20 +0000 2015',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '✨Native Texan 🇨🇱 ✨ VP of Field Relations in Orange County, CA ✨Political News Contributor ✨Mindset/Leadership Speaker✨Independent✨',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'tinyurl.com/yawp5j9v',
#          'expanded_url': 'https://tinyurl.com/yawp5j9v',
#          'indices': [0, 23],
#          'url': 'https://t.co/yKGoetg6lc'}]}},
#      'favourites_count': 54447,
#      'follow_request_sent': False,
#      'followers_count': 107779,
#      'following': False,
#      'friends_count': 1524,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 3995778614,
#      'id_str': '3995778614',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 419,
#      'location': 'Los Angeles, CA ✈️ Dallas, TX',
#      'name': 'Kambree Kawahine Koa',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3995778614/1512949404',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_link_color': '221122',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'KamVTV',
#      'statuses_count': 49374,
#      'time_zone': None,
# ...
#      'has_extended_profile': True,
#      'id': 3995778614,
#      'id_str': '3995778614',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 419,
#      'location': 'Los Angeles, CA ✈️ Dallas, TX',
#      'name': 'Kambree Kawahine Koa',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3995778614/1512949404',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_link_color': '221122',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'KamVTV',
#      'statuses_count': 49374,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/yKGoetg6lc',
#      'utc_offset': None,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @KamVTV: I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 billion. Gavin N…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Nov 19 01:58:28 +0000 2014',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'I am a Christian. I love my husband, children, my grand baby, my Country and my President!  I am a proud conservative. And love the U!!!',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 20415,
#     'follow_request_sent': False,
#     'followers_count': 510,
#     'following': False,
#     'friends_count': 497,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2904084925,
#     'id_str': '2904084925',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 1,
#     'location': '',
#     'name': 'Sue Delapena',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/537449084643454976/MaPJxWNc_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/537449084643454976/MaPJxWNc_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MySuebell42',
#     'statuses_count': 7115,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:07:03 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3995778614,
#       'id_str': '3995778614',
#       'indices': [3, 10],
#       'name': 'Kambree Kawahine Koa',
#       'screen_name': 'KamVTV'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006719566582599680,
#    'id_str': '1006719566582599680',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 293,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Jun 12 23:23:29 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1006678403355852800',
#        'indices': [117, 140],
#        'url': 'https://t.co/jNEkRd0E09'}],
#      'user_mentions': []},
#     'favorite_count': 334,
#     'favorited': False,
#     'geo': None,
#     'id': 1006678403355852800,
#     'id_str': '1006678403355852800',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 293,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 bill… https://t.co/jNEkRd0E09',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Oct 23 22:32:20 +0000 2015',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': '✨Native Texan 🇨🇱 ✨ VP of Field Relations in Orange County, CA ✨Political News Contributor ✨Mindset/Leadership Speaker✨Independent✨',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'tinyurl.com/yawp5j9v',
#          'expanded_url': 'https://tinyurl.com/yawp5j9v',
#          'indices': [0, 23],
#          'url': 'https://t.co/yKGoetg6lc'}]}},
#      'favourites_count': 54447,
#      'follow_request_sent': False,
#      'followers_count': 107779,
#      'following': False,
#      'friends_count': 1524,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 3995778614,
#      'id_str': '3995778614',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 419,
#      'location': 'Los Angeles, CA ✈️ Dallas, TX',
#      'name': 'Kambree Kawahine Koa',
#      'notifications': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3995778614/1512949404',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/989915657654288384/KNheH_Uw_normal.jpg',
#      'profile_link_color': '221122',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'KamVTV',
#      'statuses_count': 49374,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/yKGoetg6lc',
#      'utc_offset': None,
#      'verified': True}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @KamVTV: I just paid OVER $4 for gas!\n\nJerry Brown just signed bill to increase gas taxes and vehicle fees to raise $52 billion. Gavin N…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jul 15 11:33:44 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '(R) Reformed democrat. Hitting this with eyes wide open. My defiance Trumps their protest! No Ads No List #MAGA #SethRich #Justice #LOCKHERUP #Determination',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'Gab.ai/mrmac420',
#         'expanded_url': 'http://Gab.ai/mrmac420',
#         'indices': [0, 23],
#         'url': 'https://t.co/SGWjsEnCI1'}]}},
#     'favourites_count': 28628,
#     'follow_request_sent': False,
#     'followers_count': 6772,
#     'following': False,
#     'friends_count': 7356,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 335874505,
#     'id_str': '335874505',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 3,
#     'location': 'New Hampshire, USA',
#     'name': '{MIKE}',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/335874505/1477959482',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/803082395859619841/tRfX_05i_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/803082395859619841/tRfX_05i_normal.jpg',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'mrmac420',
#     'statuses_count': 22483,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/SGWjsEnCI1',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Jun 13 02:06:39 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'paper.li/JanSKay?read=h…',
#       'expanded_url': 'https://paper.li/JanSKay?read=https%3A%2F%2Fwww.yahoo.com%2Fnews%2Fcalifornias-gavin-newsom-wants-lead-way-post-bernie-post-hillary-party-160041273.html',
#       'indices': [102, 125],
#       'url': 'https://t.co/u5MseFkC5P'}],
#     'user_mentions': [{'id': 1199596897,
#       'id_str': '1199596897',
#       'indices': [3, 15],
#       'name': 'John Michael Medina',
#       'screen_name': 'CcriderJohn'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1006719468742103040,
#    'id_str': '1006719468742103040',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Jun 13 01:37:26 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'paper.li/JanSKay?read=h…',
#        'expanded_url': 'https://paper.li/JanSKay?read=https%3A%2F%2Fwww.yahoo.com%2Fnews%2Fcalifornias-gavin-newsom-wants-lead-way-post-bernie-post-hillary-party-160041273.html',
#        'indices': [85, 108],
#        'url': 'https://t.co/u5MseFkC5P'}],
#      'user_mentions': []},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 1006712112838668289,
#     'id_str': '1006712112838668289',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': "California's Gavin Newsom wants to lead the way to a post-Bernie, post-Hillary party https://t.co/u5MseFkC5P",
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Feb 20 04:54:40 +0000 2013',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': "I am a liberal and damn proud of it! I'm a true Christian! I care about the poor and seniors!",
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 8203,
#      'follow_request_sent': False,
#      'followers_count': 8787,
#      'following': False,
#      'friends_count': 9618,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 1199596897,
#      'id_str': '1199596897',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 126,
#      'location': '',
#      'name': 'John Michael Medina',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1199596897/1398323091',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/3691548349/fd6e74392ef07ff47309d583d1cfa590_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3691548349/fd6e74392ef07ff47309d583d1cfa590_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'CcriderJohn',
#      'statuses_count': 66677,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "RT @CcriderJohn: California's Gavin Newsom wants to lead the way to a post-Bernie, post-Hillary party https://t.co/u5MseFkC5P",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Nov 15 20:26:13 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Progressive Rascal! Gun Grabber 💪 Anti-GOP Warrior!  Plant 🌿 & 🐾 Animal Lover',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 28811,
#     'follow_request_sent': False,
#     'followers_count': 2075,
#     'following': False,
#     'friends_count': 1660,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 413378862,
#     'id_str': '413378862',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 49,
#     'location': 'Chicago, USA, Planet Earth',
#     'name': 'SqueekyLeaks',
#     'notifications': False,
#     'profile_background_color': '3B94D9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/413378862/1452046629',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000392689005/89bae9ad624fc333875421f28db6870b_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000392689005/89bae9ad624fc333875421f28db6870b_normal.jpeg',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'squeekyleaks',
#     'statuses_count': 50264,
#     'time_zone': None,
#     'translator_type': 'regular',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}}]}

# %%
# Search for People Tweeting about Mark Hamill
search_term = "Gavin Newsom"

# Create variable for holding the oldest tweet
oldest_tweet = None

# List to hold unique IDs
unique_ids = []
results = []

# Counter to keep track of the number of tweets retrieved
counter = 0

# Loop through 5 times (total of 500 tweets)
for x in range(5):

    # Retrieve 100 most recent tweets -- specifying a max_id
    public_tweets = api.search(search_term, 
                               count=100,
                               result_type="recent", 
                               max_id=oldest_tweet)

    # Print Tweets
    for tweet in public_tweets["statuses"]:
        
        tweet_id = tweet_id = tweet["id"]
        
        # Use filters to check if user meets conditions
        if (tweet["user"]["followers_count"] < max_followers and
            tweet["user"]["statuses_count"] > min_tweets and
            tweet["user"]["statuses_count"] < max_tweets and
            tweet["user"]["friends_count"] < max_following and
                tweet["user"]["lang"] == lang):

            # Print the username
            #print(tweet["user"]["screen_name"])

            # Print the tweet id
            #print(tweet["id_str"])

            # Print the tweet text
            #print(tweet["text"])
            #print()

            # Print the tweet date
            #print(tweet["created_at"])
            #print()
            
            # Append tweet_id to ids list if it doesn't already exist
            # This allows checking for duplicate tweets
            if tweet_id not in unique_ids:
                unique_ids.append(tweet_id)
                
                

            # Increase counter by 1
            counter += 1
            results.append({"User": tweet["user"]["screen_name"],
                           "Tweet": tweet["text"],
                           "Date": tweet["created_at"],
                           "Tweet ID Str": tweet["id_str"],
                           "Tweet ID": tweet["id"],
                           "Candidate": search_term})
            
        # Reassign the the oldest tweet (i.e. the max_id)
        # Subtract 1 so the previous oldest isn't included
        # in the new search
        oldest_tweet = tweet_id - 1

# %%
len(results)
# Out:
# 127

# %%
results_pd = pd.DataFrame.from_dict(results)
results_pd.head()
# Out:
#       Candidate                            Date  \
# 0  Gavin Newsom  Wed Jun 13 02:19:21 +0000 2018
# 1  Gavin Newsom  Wed Jun 13 02:11:51 +0000 2018
# 2  Gavin Newsom  Wed Jun 13 02:07:27 +0000 2018
# 3  Gavin Newsom  Wed Jun 13 02:04:10 +0000 2018
# 4  Gavin Newsom  Wed Jun 13 01:53:07 +0000 2018
#
#                                                Tweet             Tweet ID  \
# 0  RT @KamVTV: I just paid OVER $4 for gas!\n\nJe...  1006722662549344256
# 1  @Kate1Kincaid @skramerbyu_82 Unfortunately, it...  1006720776882479106
# 2  RT @KamVTV: I just paid OVER $4 for gas!\n\nJe...  1006719669108199430
# 3  The loudest cheers were for KD (w/ MVP chants)...  1006718841643077632
# 4  RT @KamVTV: I just paid OVER $4 for gas!\n\nJe...  1006716060358225920
#
#           Tweet ID Str            User
# 0  1006722662549344256       J44morris
# 1  1006720776882479106  Leslie97606493
# 2  1006719669108199430     MySuebell42
# 3  1006718841643077632  _emptyyourmind
# 4  1006716060358225920          tblbkb

# %%
# Print total number of tweets retrieved
print(counter)
# Out:
# 129

# %%
# Print the number of unique ids retrieved
print(len(unique_ids))
# Out:
# 129

# %%
# Export to CSV
file_name = str(time.strftime("%m-%d-%y")) + "-Tweets.csv"
results_pd.to_csv(file_name, encoding="utf-8")
