# %%
import pandas as pd
import matplotlib.pyplot as plt

ride_data = pd.read_csv("raw_data/ride_data.csv")
city_data = pd.read_csv("raw_data/ride_data.csv")
# ride_summary

# ride_summary = ride_data.groupby("city")

# ride_summary["Average Fare ($) Per City"] = ride_data.groupby(["city"]).mean()["fare"].map("${:,.2f}".format)
# ride_summary["Total Number of Rides Per City"] = ride_data.groupby(["city"]).count()["ride_id"]

# ride_summary.head()


#creating data frames
ride_df = pd.DataFrame({
    "city": ride_data.groupby(["city"]),
    "Average Fare ($) Per City": ride_data.groupby(["city"]).mean()["fare"].map("${:,.2f}".format),
    "Total Number of Rides Per City": ride_data.groupby(["city"]).count()["ride_id"]
})

city_df = city_data.set_index("city")

#creating data frames
ride_df.head()
# city_df.head()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     393                             if callable(meth):
#     394                                 return meth(obj, self, cycle)
# --> 395             return _default_pprint(obj, self, cycle)
#     396         finally:
#     397             self.end_group()
#
# ~\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _default_pprint(obj, p, cycle)
#     508     if _safe_getattr(klass, '__repr__', None) is not object.__repr__:
# ...

# %%
ride_df.columns
# Out:
# Index(['Average Fare ($) Per City', 'Total Number of Rides Per City'], dtype='object')

# %%
asdf = ["asdf","fdsa"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-4b08ca98f37d> in <module>()
#       1 asdf = ["asdf","fdsa"]
# ----> 2 describe(asdf)
#
# NameError: name 'describe' is not defined

# %%
city_df.dtypes
# Out:
# date        object
# fare       float64
# ride_id      int64
# dtype: object

# %%
pd.to

# %%
# 

merged_df = pd.merge(ride_df,city_df,on="city",how="outer")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-b9429f930de3> in <module>()
#       1 #
#       2
# ...
