# %%
import pandas as pd
import matplotlib.pyplot as plt

ride_data = pd.read_csv("raw_data/ride_data.csv")
city_data = pd.read_csv("raw_data/ride_data.csv")

ride_df = pd.DataFrame({
    "Average Fare ($) Per City": ride_data.groupby(["city"]).mean()["fare"].map("${:,.2f}".format),
    "Total Number of Rides Per City": ride_data.groupby(["city"]).count()["ride_id"]
})

ride_df_reset = ride_data.reset_index()
city_df_reset = city_data.reset_index()

ride_df_reset
# Out:
#       index                  city                 date   fare        ride_id
# 0         0              Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1         1             South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2         2           Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3         3           Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4         4            Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673
# 5         5           New Jeffrey  2016-02-22 18:36:25  36.01  9757888452346
# 6         6         Port Johnstad  2016-06-07 02:39:58  17.15  4352278259335
# 7         7             Jacobfort  2016-09-20 20:58:37  22.98  1500221409082
# 8         8           Travisville  2016-01-15 17:32:02  27.39   850152768361
# 9         9            Sandymouth  2016-11-16 07:27:00  21.61  2389035050524
# 10       10       New Andreamouth  2016-04-11 07:20:48   7.72  9992929847990
# ...

# %%
city_data
# Out:
#                       city                 date   fare        ride_id
# 0                 Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1                South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 2              Wiseborough  2016-01-21 17:35:29  44.18  3645042422587
# 3              Spencertown  2016-07-31 14:53:22   6.87  2242596575892
# 4               Nguyenbury  2016-07-09 04:42:44   6.28  1543057793673
# 5              New Jeffrey  2016-02-22 18:36:25  36.01  9757888452346
# 6            Port Johnstad  2016-06-07 02:39:58  17.15  4352278259335
# 7                Jacobfort  2016-09-20 20:58:37  22.98  1500221409082
# 8              Travisville  2016-01-15 17:32:02  27.39   850152768361
# 9               Sandymouth  2016-11-16 07:27:00  21.61  2389035050524
# 10         New Andreamouth  2016-04-11 07:20:48   7.72  9992929847990
# 11           New Christine  2016-09-13 15:06:42  24.89  7918411468537
# ...

# %%
merged_df = pd.merge(ride_df_reset,city_df_reset,on="city",how="inner")
merged_df
# Out:
#        index_x                  city               date_x  fare_x  \
# 0            0              Sarabury  2016-01-16 13:49:27   38.35
# 1            0              Sarabury  2016-01-16 13:49:27   38.35
# 2            0              Sarabury  2016-01-16 13:49:27   38.35
# 3            0              Sarabury  2016-01-16 13:49:27   38.35
# 4            0              Sarabury  2016-01-16 13:49:27   38.35
# 5            0              Sarabury  2016-01-16 13:49:27   38.35
# 6            0              Sarabury  2016-01-16 13:49:27   38.35
# 7            0              Sarabury  2016-01-16 13:49:27   38.35
# 8            0              Sarabury  2016-01-16 13:49:27   38.35
# 9            0              Sarabury  2016-01-16 13:49:27   38.35
# 10           0              Sarabury  2016-01-16 13:49:27   38.35
# 11           0              Sarabury  2016-01-16 13:49:27   38.35
# 12           0              Sarabury  2016-01-16 13:49:27   38.35
# ...
